# %% [markdown]
# <a href="https://colab.research.google.com/github/JanMarcelKezmann/Residual-Network-Architectures/blob/master/Inception_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import tensorflow as tf

from IPython.display import SVG
from matplotlib.pyplot import imshow
# %matplotlib inline

from sklearn.utils import shuffle
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.model_selection import train_test_split

import tensorflow.keras.backend as K
K.set_image_data_format("channels_last")
K.set_learning_phase(1)

from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Add, Dense, Dropout, Lambda, Flatten, Concatenate, Input, Conv2D, Activation, BatchNormalization, AveragePooling2D, ZeroPadding2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import regularizers, activations

# %%
def inception_block_a(X, block):
    name = "inc_block_a" + block

    # Branch 1
    branch1 = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch1", padding="same", kernel_initializer=glorot_uniform(seed=0))(X)

    # Branch 2
    X_padded = ZeroPadding2D((1, 1), name=name + "_zeros")(X)
    branch2 = AveragePooling2D((3, 3), strides=(1, 1), name=name + "_avgpool")(X_padded)
    branch2 = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch2", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch2)

    # Branch 3
    branch3 = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch3_0", padding="same", kernel_initializer=glorot_uniform(seed=0))(X)
    #   branch3_padded = ZeroPadding2D((1, 1))(branch3)
    branch3 = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), name=name + "_branch3_1", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch3)

    # Branch 4
    branch4 = Conv2D(filters=64, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch4_0", padding="same", kernel_initializer=glorot_uniform(seed=0))(X)
    #   branch4_padded = ZeroPadding2D((1, 1))(branch4)
    branch4 = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), name=name + "_branch4_1", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
    branch4 = Conv2D(filters=96, kernel_size=(3, 3), strides=(1, 1), name=name + "_branch4_2", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)

    branches = [branch1, branch2, branch3, branch4]

    mixed = Concatenate(axis=3, name=name + "_concat")(branches)
    mixed = BatchNormalization(axis=3, name=name + "_bn")(mixed)
    mixed = Activation("relu", name=name + "_activate")(mixed)

    return mixed

# %%
def inception_block_b(X, block, n=7, strides_bool=False):
    if strides_bool:
        strides = 2
    else:
        strides = 1

    name = "inc_block_b" + block

    m = int(math.floor((n - 1) / 2))

    # Branch 1
    if strides_bool:
        branch1 = Conv2D(filters=192, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    else:
        branch1 = Conv2D(filters=192, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)

    # Branch 2
    X_padded = ZeroPadding2D((1, 1), name=name + "_zeros")(X)
    branch2 = AveragePooling2D((3, 3), strides=(1, 1), name=name + "_avgpool")(X_padded)
    if strides_bool:
        branch2 = Conv2D(filters=192, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch2", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch2)
    else:
        branch2 = Conv2D(filters=192, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch2", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch2)

    # Branch 3
    branch3 = Conv2D(filters=192, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch3_0", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    if strides_bool:
        branch3 = Conv2D(filters=192, kernel_size=(m, m), strides=(strides, strides), name=name + "_branch3_1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch3)
    else:
        #   branch3_padded = ZeroPadding2D((m, m))(branch3)
        branch3 = Conv2D(filters=192, kernel_size=(1, n), strides=(1, 1), name=name + "_branch3_1", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch3)
        branch3 = Conv2D(filters=192, kernel_size=(n, 1), strides=(1, 1), name=name + "_branch3_2", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch3)

    # Branch 4
    branch4 = Conv2D(filters=192, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch4_0", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    if strides_bool:
        branch4 = Conv2D(filters=192, kernel_size=(m, m), strides=(1, 1), name=name + "_branch4_1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch4)
        branch4 = Conv2D(filters=192, kernel_size=(m, m), strides=(strides, strides), name=name + "_branch4_3", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
    else:
        #   branch4_padded = ZeroPadding((m, m))(branch4)
        branch4 = Conv2D(filters=192, kernel_size=(1, n), strides=(1, 1), name=name + "_branch4_1", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
        branch4 = Conv2D(filters=192, kernel_size=(n, 1), strides=(1, 1), name=name + "_branch4_2", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
        #   branch4_padded = ZeroPadding((m, m))(branch4)
        branch4 = Conv2D(filters=192, kernel_size=(1, n), strides=(1, 1), name=name + "_branch4_3", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
        branch4 = Conv2D(filters=192, kernel_size=(n, 1), strides=(1, 1), name=name + "_branch4_4", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)

    branches = [branch1, branch2, branch3, branch4]

    mixed = Concatenate(axis=3, name=name + "_concat")(branches)
    mixed = BatchNormalization(axis=3, name=name + "_bn")(mixed)
    mixed = Activation("relu", name=name + "_activate")(mixed)

    return mixed

# %%
def inception_block_c(X, block, strides_bool=False):
    if strides_bool:
        strides = 2
    else:
        strides = 1

    name = "inc_block_c" + block

    # Branch 1
    if strides_bool:
        branch1 = Conv2D(filters=320, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    else:
        branch1 = Conv2D(filters=320, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)

    # Branch 2
    X_padded = ZeroPadding2D((1, 1), name=name + "_zeros")(X)
    branch2 = AveragePooling2D((3, 3), strides=(1, 1), name=name + "_avgpool")(X_padded)
    if strides_bool:
        branch2 = Conv2D(filters=192, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch2", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch2)
    else:
        branch2 = Conv2D(filters=192, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch2", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch2)

    # Branch 3
    branch3 = Conv2D(filters=384, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch3_0", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    if strides_bool:
        branch3 = Conv2D(filters=384, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch3_1", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch3)
    else:
        #   branch3_padded = ZeroPadding2D((1, 1))(branch3)
        branch3a = Conv2D(filters=384, kernel_size=(1, 3), strides=(1, 1), name=name + "_branch3_1a", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch3)
        branch3b = Conv2D(filters=384, kernel_size=(3, 1), strides=(1, 1), name=name + "_branch3_1b", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch3)

    # Branch 4
    branch4 = Conv2D(filters=384, kernel_size=(1, 1), strides=(1, 1), name=name + "_branch4_0", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    #   branch4_padded = ZeroPadding2D((1, 1))(branch4)
    branch4 = Conv2D(filters=384, kernel_size=(3, 3), strides=(1, 1), name=name + "_branch4_1", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
    if strides_bool:
        branch4 = Conv2D(filters=384, kernel_size=(3, 3), strides=(strides, strides), name=name + "_branch4_2", padding="valid", kernel_initializer=glorot_uniform(seed=0))(branch4)
    else:
        #   branch4_padded = ZeroPadding2D((1, 1))(branch4)
        branch4a = Conv2D(filters=384, kernel_size=(1, 3), strides=(1, 1), name=name + "_branch4_2a", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)
        branch4b = Conv2D(filters=384, kernel_size=(3, 1), strides=(1, 1), name=name + "_branch4_2b", padding="same", kernel_initializer=glorot_uniform(seed=0))(branch4)

    if strides_bool:
        branches = [branch1, branch2, branch3, branch4]
    else:
        branches = [branch1, branch2, branch3a, branch3b, branch4a, branch4b]

    mixed = Concatenate(axis=3, name=name + "_concat")(branches)
    mixed = BatchNormalization(axis=3, name=name + "_bn")(mixed)
    mixed = Activation("relu", name=name + "_activate")(mixed)

    return mixed

# %%
def inception_v3(input_shape=(299, 299, 3), classes=1000):
    # Define Input as tensor with input_shape as shape
    X_input = Input(input_shape)

    #   ZeroPadding2D((3, 3))(X_input) (adds 3 zeros on each side)
    #   X = ZeroPadding2D((3, 3))(X_input)
    #   print(X.shape) # should be (n + 3, n + 3, 3)

    # Stage 1
    X = Conv2D(filters=32, kernel_size=(3, 3), strides=(2, 2), name="conv1a", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X_input)
    X = Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), name="conv1b", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    X = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), name="conv1c", padding="same", kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name="conv1_bn1")(X)
    X = Activation("relu")(X)

    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = Conv2D(filters=80, kernel_size=(3, 3), strides=(1, 1), name="conv1d", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    X = Conv2D(filters=192, kernel_size=(3, 3), strides=(2, 2), name="conv1e", padding="valid", kernel_initializer=glorot_uniform(seed=0))(X)
    X = Conv2D(filters=192, kernel_size=(3, 3), strides=(1, 1), name="conv1f", padding="same", kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name="conv1_bn2")(X)
    X = Activation("relu")(X)

    # Inception A Block
    X = inception_block_a(X, block="_round1")
    X = inception_block_a(X, block="_round2")
    X = inception_block_a(X, block="_round3")

    # Inception B Block
    X = inception_block_b(X, block="_round1", n=7, strides_bool=True)
    X = inception_block_b(X, block="_round2", n=7)
    X = inception_block_b(X, block="_round3", n=7)
    X = inception_block_b(X, block="_round4", n=7)
    X = inception_block_b(X, block="_round5", n=7)

    # Inception C Block
    X = inception_block_c(X, block="_round1", strides_bool=True)
    X = inception_block_c(X, block="_round2")

    # Final Pooling and Dense Layer
    X = AveragePooling2D((8, 8))(X) # could this be replaced by 1x8 and 8x1 pooling?
    #   X = AveragePooling2D((1, 8))(X)
    #   X = AveragePooling2D((8, 1))(X)
    
    X = Flatten()(X) # if dimension before flatten is 1x1x2048 than flatten can be removed
    X = Dense(classes, activation="softmax", name="inception_v3_fc", kernel_initializer=glorot_uniform(seed=0))(X)

    # Create Model
    model = Model(inputs=X_input, outputs=X, name="Inception_V3")

    return model

# %%
model = inception_v3()

# %%
model.summary()
# Out:
# Model: "Inception_V3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv1a (Conv2D)                 (None, 149, 149, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# conv1b (Conv2D)                 (None, 147, 147, 32) 9248        conv1a[0][0]
# __________________________________________________________________________________________________
# conv1c (Conv2D)                 (None, 147, 147, 64) 18496       conv1b[0][0]
# __________________________________________________________________________________________________
# conv1_bn1 (BatchNormalization)  (None, 147, 147, 64) 256         conv1c[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           conv1_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv2D)                 (None, 71, 71, 80)   46160       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv1e (Conv2D)                 (None, 35, 35, 192)  138432      conv1d[0][0]
# __________________________________________________________________________________________________
# conv1f (Conv2D)                 (None, 35, 35, 192)  331968      conv1e[0][0]
# __________________________________________________________________________________________________
# conv1_bn2 (BatchNormalization)  (None, 35, 35, 192)  768         conv1f[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 35, 35, 192)  0           conv1_bn2[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_zeros (ZeroP (None, 37, 37, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_branch4_0 (C (None, 35, 35, 64)   12352       activation_3[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_avgpool (Ave (None, 35, 35, 192)  0           inc_block_a_round1_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_branch3_0 (C (None, 35, 35, 64)   12352       activation_3[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_branch4_1 (C (None, 35, 35, 64)   36928       inc_block_a_round1_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round1_branch1 (Con (None, 35, 35, 64)   12352       activation_3[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_branch2 (Con (None, 35, 35, 64)   12352       inc_block_a_round1_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_branch3_1 (C (None, 35, 35, 64)   36928       inc_block_a_round1_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round1_branch4_2 (C (None, 35, 35, 96)   55392       inc_block_a_round1_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_a_round1_concat (Conc (None, 35, 35, 288)  0           inc_block_a_round1_branch1[0][0]
#                                                                  inc_block_a_round1_branch2[0][0]
#                                                                  inc_block_a_round1_branch3_1[0][0
#                                                                  inc_block_a_round1_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_a_round1_bn (BatchNor (None, 35, 35, 288)  1152        inc_block_a_round1_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round1_activate (Ac (None, 35, 35, 288)  0           inc_block_a_round1_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_zeros (ZeroP (None, 37, 37, 288)  0           inc_block_a_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_branch4_0 (C (None, 35, 35, 64)   18496       inc_block_a_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_avgpool (Ave (None, 35, 35, 288)  0           inc_block_a_round2_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_branch3_0 (C (None, 35, 35, 64)   18496       inc_block_a_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_branch4_1 (C (None, 35, 35, 64)   36928       inc_block_a_round2_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round2_branch1 (Con (None, 35, 35, 64)   18496       inc_block_a_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_branch2 (Con (None, 35, 35, 64)   18496       inc_block_a_round2_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_branch3_1 (C (None, 35, 35, 64)   36928       inc_block_a_round2_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round2_branch4_2 (C (None, 35, 35, 96)   55392       inc_block_a_round2_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_a_round2_concat (Conc (None, 35, 35, 288)  0           inc_block_a_round2_branch1[0][0]
#                                                                  inc_block_a_round2_branch2[0][0]
#                                                                  inc_block_a_round2_branch3_1[0][0
#                                                                  inc_block_a_round2_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_a_round2_bn (BatchNor (None, 35, 35, 288)  1152        inc_block_a_round2_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round2_activate (Ac (None, 35, 35, 288)  0           inc_block_a_round2_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_zeros (ZeroP (None, 37, 37, 288)  0           inc_block_a_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_branch4_0 (C (None, 35, 35, 64)   18496       inc_block_a_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_avgpool (Ave (None, 35, 35, 288)  0           inc_block_a_round3_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_branch3_0 (C (None, 35, 35, 64)   18496       inc_block_a_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_branch4_1 (C (None, 35, 35, 64)   36928       inc_block_a_round3_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round3_branch1 (Con (None, 35, 35, 64)   18496       inc_block_a_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_branch2 (Con (None, 35, 35, 64)   18496       inc_block_a_round3_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_branch3_1 (C (None, 35, 35, 64)   36928       inc_block_a_round3_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_a_round3_branch4_2 (C (None, 35, 35, 96)   55392       inc_block_a_round3_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_a_round3_concat (Conc (None, 35, 35, 288)  0           inc_block_a_round3_branch1[0][0]
#                                                                  inc_block_a_round3_branch2[0][0]
#                                                                  inc_block_a_round3_branch3_1[0][0
#                                                                  inc_block_a_round3_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_a_round3_bn (BatchNor (None, 35, 35, 288)  1152        inc_block_a_round3_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_a_round3_activate (Ac (None, 35, 35, 288)  0           inc_block_a_round3_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_zeros (ZeroP (None, 37, 37, 288)  0           inc_block_a_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_branch4_0 (C (None, 35, 35, 192)  55488       inc_block_a_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_avgpool (Ave (None, 35, 35, 288)  0           inc_block_b_round1_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_branch3_0 (C (None, 35, 35, 192)  55488       inc_block_a_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_branch4_1 (C (None, 33, 33, 192)  331968      inc_block_b_round1_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round1_branch1 (Con (None, 17, 17, 192)  497856      inc_block_a_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_branch2 (Con (None, 17, 17, 192)  497856      inc_block_b_round1_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_branch3_1 (C (None, 17, 17, 192)  331968      inc_block_b_round1_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round1_branch4_3 (C (None, 17, 17, 192)  331968      inc_block_b_round1_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round1_concat (Conc (None, 17, 17, 768)  0           inc_block_b_round1_branch1[0][0]
#                                                                  inc_block_b_round1_branch2[0][0]
#                                                                  inc_block_b_round1_branch3_1[0][0
#                                                                  inc_block_b_round1_branch4_3[0][0
# __________________________________________________________________________________________________
# inc_block_b_round1_bn (BatchNor (None, 17, 17, 768)  3072        inc_block_b_round1_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round1_activate (Ac (None, 17, 17, 768)  0           inc_block_b_round1_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch4_0 (C (None, 17, 17, 192)  147648      inc_block_b_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch4_1 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_zeros (ZeroP (None, 19, 19, 768)  0           inc_block_b_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch3_0 (C (None, 17, 17, 192)  147648      inc_block_b_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch4_2 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_avgpool (Ave (None, 17, 17, 768)  0           inc_block_b_round2_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch3_1 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_branch4_3 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_branch1 (Con (None, 17, 17, 192)  147648      inc_block_b_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch2 (Con (None, 17, 17, 192)  147648      inc_block_b_round2_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_branch3_2 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch3_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_branch4_4 (C (None, 17, 17, 192)  258240      inc_block_b_round2_branch4_3[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_concat (Conc (None, 17, 17, 768)  0           inc_block_b_round2_branch1[0][0]
#                                                                  inc_block_b_round2_branch2[0][0]
#                                                                  inc_block_b_round2_branch3_2[0][0
#                                                                  inc_block_b_round2_branch4_4[0][0
# __________________________________________________________________________________________________
# inc_block_b_round2_bn (BatchNor (None, 17, 17, 768)  3072        inc_block_b_round2_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round2_activate (Ac (None, 17, 17, 768)  0           inc_block_b_round2_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch4_0 (C (None, 17, 17, 192)  147648      inc_block_b_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch4_1 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_zeros (ZeroP (None, 19, 19, 768)  0           inc_block_b_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch3_0 (C (None, 17, 17, 192)  147648      inc_block_b_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch4_2 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_avgpool (Ave (None, 17, 17, 768)  0           inc_block_b_round3_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch3_1 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_branch4_3 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_branch1 (Con (None, 17, 17, 192)  147648      inc_block_b_round2_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch2 (Con (None, 17, 17, 192)  147648      inc_block_b_round3_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_branch3_2 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch3_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_branch4_4 (C (None, 17, 17, 192)  258240      inc_block_b_round3_branch4_3[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_concat (Conc (None, 17, 17, 768)  0           inc_block_b_round3_branch1[0][0]
#                                                                  inc_block_b_round3_branch2[0][0]
#                                                                  inc_block_b_round3_branch3_2[0][0
#                                                                  inc_block_b_round3_branch4_4[0][0
# __________________________________________________________________________________________________
# inc_block_b_round3_bn (BatchNor (None, 17, 17, 768)  3072        inc_block_b_round3_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round3_activate (Ac (None, 17, 17, 768)  0           inc_block_b_round3_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch4_0 (C (None, 17, 17, 192)  147648      inc_block_b_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch4_1 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_zeros (ZeroP (None, 19, 19, 768)  0           inc_block_b_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch3_0 (C (None, 17, 17, 192)  147648      inc_block_b_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch4_2 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_avgpool (Ave (None, 17, 17, 768)  0           inc_block_b_round4_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch3_1 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_branch4_3 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_branch1 (Con (None, 17, 17, 192)  147648      inc_block_b_round3_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch2 (Con (None, 17, 17, 192)  147648      inc_block_b_round4_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_branch3_2 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch3_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_branch4_4 (C (None, 17, 17, 192)  258240      inc_block_b_round4_branch4_3[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_concat (Conc (None, 17, 17, 768)  0           inc_block_b_round4_branch1[0][0]
#                                                                  inc_block_b_round4_branch2[0][0]
#                                                                  inc_block_b_round4_branch3_2[0][0
#                                                                  inc_block_b_round4_branch4_4[0][0
# __________________________________________________________________________________________________
# inc_block_b_round4_bn (BatchNor (None, 17, 17, 768)  3072        inc_block_b_round4_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round4_activate (Ac (None, 17, 17, 768)  0           inc_block_b_round4_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch4_0 (C (None, 17, 17, 192)  147648      inc_block_b_round4_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch4_1 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_zeros (ZeroP (None, 19, 19, 768)  0           inc_block_b_round4_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch3_0 (C (None, 17, 17, 192)  147648      inc_block_b_round4_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch4_2 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_avgpool (Ave (None, 17, 17, 768)  0           inc_block_b_round5_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch3_1 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_branch4_3 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_branch1 (Con (None, 17, 17, 192)  147648      inc_block_b_round4_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch2 (Con (None, 17, 17, 192)  147648      inc_block_b_round5_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_branch3_2 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch3_1[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_branch4_4 (C (None, 17, 17, 192)  258240      inc_block_b_round5_branch4_3[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_concat (Conc (None, 17, 17, 768)  0           inc_block_b_round5_branch1[0][0]
#                                                                  inc_block_b_round5_branch2[0][0]
#                                                                  inc_block_b_round5_branch3_2[0][0
#                                                                  inc_block_b_round5_branch4_4[0][0
# __________________________________________________________________________________________________
# inc_block_b_round5_bn (BatchNor (None, 17, 17, 768)  3072        inc_block_b_round5_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_b_round5_activate (Ac (None, 17, 17, 768)  0           inc_block_b_round5_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_zeros (ZeroP (None, 19, 19, 768)  0           inc_block_b_round5_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_branch4_0 (C (None, 17, 17, 384)  295296      inc_block_b_round5_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_avgpool (Ave (None, 17, 17, 768)  0           inc_block_c_round1_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_branch3_0 (C (None, 17, 17, 384)  295296      inc_block_b_round5_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_branch4_1 (C (None, 17, 17, 384)  1327488     inc_block_c_round1_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_c_round1_branch1 (Con (None, 8, 8, 320)    2212160     inc_block_b_round5_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_branch2 (Con (None, 8, 8, 192)    1327296     inc_block_c_round1_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_branch3_1 (C (None, 8, 8, 384)    1327488     inc_block_c_round1_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_c_round1_branch4_2 (C (None, 8, 8, 384)    1327488     inc_block_c_round1_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_c_round1_concat (Conc (None, 8, 8, 1280)   0           inc_block_c_round1_branch1[0][0]
#                                                                  inc_block_c_round1_branch2[0][0]
#                                                                  inc_block_c_round1_branch3_1[0][0
#                                                                  inc_block_c_round1_branch4_2[0][0
# __________________________________________________________________________________________________
# inc_block_c_round1_bn (BatchNor (None, 8, 8, 1280)   5120        inc_block_c_round1_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round1_activate (Ac (None, 8, 8, 1280)   0           inc_block_c_round1_bn[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_zeros (ZeroP (None, 10, 10, 1280) 0           inc_block_c_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_branch4_0 (C (None, 8, 8, 384)    491904      inc_block_c_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_avgpool (Ave (None, 8, 8, 1280)   0           inc_block_c_round2_zeros[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_branch3_0 (C (None, 8, 8, 384)    491904      inc_block_c_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_branch4_1 (C (None, 8, 8, 384)    1327488     inc_block_c_round2_branch4_0[0][0
# __________________________________________________________________________________________________
# inc_block_c_round2_branch1 (Con (None, 8, 8, 320)    409920      inc_block_c_round1_activate[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_branch2 (Con (None, 8, 8, 192)    245952      inc_block_c_round2_avgpool[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_branch3_1a ( (None, 8, 8, 384)    442752      inc_block_c_round2_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_c_round2_branch3_1b ( (None, 8, 8, 384)    442752      inc_block_c_round2_branch3_0[0][0
# __________________________________________________________________________________________________
# inc_block_c_round2_branch4_2a ( (None, 8, 8, 384)    442752      inc_block_c_round2_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_c_round2_branch4_2b ( (None, 8, 8, 384)    442752      inc_block_c_round2_branch4_1[0][0
# __________________________________________________________________________________________________
# inc_block_c_round2_concat (Conc (None, 8, 8, 2048)   0           inc_block_c_round2_branch1[0][0]
#                                                                  inc_block_c_round2_branch2[0][0]
#                                                                  inc_block_c_round2_branch3_1a[0][
#                                                                  inc_block_c_round2_branch3_1b[0][
#                                                                  inc_block_c_round2_branch4_2a[0][
#                                                                  inc_block_c_round2_branch4_2b[0][
# __________________________________________________________________________________________________
# inc_block_c_round2_bn (BatchNor (None, 8, 8, 2048)   8192        inc_block_c_round2_concat[0][0]
# __________________________________________________________________________________________________
# inc_block_c_round2_activate (Ac (None, 8, 8, 2048)   0           inc_block_c_round2_bn[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 2048)   0           inc_block_c_round2_activate[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_v3_fc (Dense)         (None, 1000)         2049000      flatten_1[0][0]
# ==================================================================================================
# Total params: 24,881,780
# Trainable params: 24,865,204
# Non-trainable params: 16,576
# __________________________________________________________________________________________________
